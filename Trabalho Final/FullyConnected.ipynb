# %%
#!/usr/bin/env python
#__author__ = 'neevsamuel'
import tensorflow as tf
import numpy as np
import time as tm

#Tensor flow executado em compatibilidade com a v1, devido aos comandos utilizados.
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 


"""
Data generation for train and test phases
"""
#

#H - Canal
#W - matriz de ruído 3d
#w - vetor de ruído aleatório gaussiano
#H_org - variável de controle pra armazenamento de valor anterior
#K - iterações no tempo

def generate_data(B,K,N,snr_low,snr_high,H_org):
    #H_=np.random.randn(B,N,K)
    W_=np.zeros([B,K,K])    #matriz com zeros
    x_=np.sign(np.random.rand(B,K)-0.5)  
    y_=np.zeros([B,N])
    w=np.random.randn(B,N)  #
    Hy_=x_*0
    H_ = np.zeros([B,N,K])
    HH_= np.zeros([B,K,K])
    SNR_= np.zeros([B])
    for i in range(B):
        #print i
        SNR = np.random.uniform(low=snr_low,high=snr_high)
        H=H_org
        tmp_snr=(H.T.dot(H)).trace()/K  #
        H_[i,:,:]=H
        y_[i,:]=(H.dot(x_[i,:])+w[i,:]*np.sqrt(tmp_snr)/np.sqrt(SNR))
        Hy_[i,:]=H.T.dot(y_[i,:])   #coleta de potência do canal
        HH_[i,:,:]=H.T.dot( H_[i,:,:])
        SNR_[i] = SNR
    return y_,H_,Hy_,HH_,x_,SNR_

#a função retorna com y (canal + ruído), H (canal atualizado), Hy e HH(Densidade de potência) e SNR.
#Dados utilizados para o treinamento do algoritmo.


def affine_layer(x,input_size,output_size,Layer_num):
    W = tf.Variable(tf.random_normal([input_size, output_size], stddev=0.01))
    w = tf.Variable(tf.random_normal([1, output_size], stddev=0.01))
    y = tf.matmul(x, W)+w
    return y

#É retornado y, na forma de ruído.

def relu_layer(x,input_size,output_size,Layer_num):
    y = tf.nn.relu(affine_layer(x,input_size,output_size,Layer_num))
    return y

#o ruído y, é normalizado.Obs: esta função, poderia ser inserida na affline_layer. É utilizada a mesma matriz y.

"""
simulation - parameters:
B - batch size
train_iter - num of train iterations
test_iter -  num of test iteration
low_snr_db_train - the low range of snr in db during train phase
high_snr_db_train - the high range of snr in db during train phase
low_snr_db_test - the low range of snr in db during test phase
high_snr_db_test - the high range of snr in db during test phase
num_snr -  number of SNRs to be tested, equally spaced between low_snr_db_test and high_snr_db_test
fc_size  -  the size of each hidden layer
startingLearningRate - the initial step size of the gradient descent algorithm
decay_factor & decay_step_size - each decay_step_size steps the learning rate decay by decay_factor
H - the channel to detect over
"""
K = 20
N = 30
B = 1000
train_iter = 1000000
test_iter = 1000
low_snr_db_train = 7.0
high_snr_db_train = 14.0
low_snr_db_test = 8.0
high_snr_db_test = 13.0
num_snr = 6
fc_size = 200
num_of_hidden_layers = 4
startingLearningRate = 0.0003
decay_factor = 0.97
decay_step_size = 1000
H=np.genfromtxt('Top06_30_20.csv', dtype=None, delimiter=',')
#end of parameters

low_snr_train = 10.0 ** (low_snr_db_train/10.0)
high_snr_train = 10.0 ** (high_snr_db_train/10.0)
low_snr_test = 10.0 ** (low_snr_db_test/10.0)
high_snr_test = 10.0 ** (high_snr_db_test/10.0)
bers = np.zeros((1,num_snr))

#São coletados os valores de SNR de teste e treinamento em dB

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.05)
    return tf.Variable(initial)

#Retorna a variável initial com distribuição truncada de dp 0.05

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

#Retorna a variável initial com constante de 0.1 (todos valores), de dimensão shape.
#Vai permitir que os valores obtidos em treinamento sejam editados.

sess = tf.compat.v1.InteractiveSession()

#Rotina de repetição do algoritmo de detecção de MIMO


NNinput = tf.placeholder(tf.float32, shape=[None, N], name='input')
org_siganl = tf.placeholder(tf.float32, shape=[None, K], name='org_siganl')
batchSize = tf.placeholder(tf.int32)

#Coletados valores para as variáveis, pra que seja plotado o gráfico posteriormente.

#The network
h_fc = []
W_fc_input = weight_variable([N, fc_size])
b_fc_input = bias_variable([fc_size])
#os valores são normalizados, e em todas as camadas do DL, a posição de bias assume valor de 0.1

h_fc.append(tf.nn.relu(tf.matmul(NNinput, W_fc_input) + b_fc_input))
#agrega valores de canais otimizados a var h_fc, considerando o melhor desempenho com ruído.


for i in range(num_of_hidden_layers):
    h_fc.append(relu_layer(h_fc[i-1],fc_size, fc_size,'relu'+str(i)))
    
    #realiza o cálculo ("convolução"), para todas as camadas do modelo DL.


W_fc_final = weight_variable([fc_size, K])
b_final= bias_variable([K])
h_final= tf.matmul(h_fc[i], W_fc_final) + b_final

#retorna os valores finais de ruído, bias e canal estimado.

ssd = tf.reduce_sum(tf.square(org_siganl - h_final))
#precisão

global_step = tf.Variable(0, trainable=False)
learning_rate = tf.train.exponential_decay(startingLearningRate, global_step, decay_step_size, decay_factor, staircase=True)
train_step = tf.train.AdamOptimizer(learning_rate).minimize(ssd)

#Ajuste de passo de treinamento e precisão (considerando ssd como melhor resultado)

val = tf.reshape(org_siganl, tf.stack([K * batchSize]))
final = tf.reshape(h_final, tf.stack([K * batchSize]))
rounded = tf.sign(final)
eq = tf.equal(rounded, val)
eq2 = tf.reduce_sum(tf.cast(eq, tf.int32))

#comparação do canal final e inicial. Formatação do canal final em int.


accuracy = ssd

sess.run(tf.global_variables_initializer())
"""
training phase og the network
"""
for i in range(train_iter):
    batch_Y, batch_H, batch_HY, batch_HH, batch_X , SNR1= generate_data(B , K , N , low_snr_train , high_snr_train , H)
    if i % 100 == 0: 
        correct_bits = eq2.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B})
        train_accuracy = accuracy.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B})
        print("step %d, loss is %g, number of correct bits %d" % (i, train_accuracy,correct_bits))
    train_step.run(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B})
    
    #calcular número de bits corretos até que o erro seja 0, ou algo próximo disso.

"""
start testing our net
"""
tmp_bers = np.zeros((1,test_iter))
tmp_times = np.zeros((1,test_iter))
times = np.zeros((1,1))
testHitCount = 0

snr_list_db = np.linspace(low_snr_db_test,high_snr_db_test,num_snr)
snr_list = 10.0**(snr_list_db/10.0)
for i_snr in range (num_snr):
    Cur_SNR = snr_list[i_snr]
    print ('cur snr')
    print (Cur_SNR)
    #medição constante do valor de SNR
    
    for i in range(test_iter):

        batch_Y, batch_H, batch_HY, batch_HH, batch_X , SNR1= generate_data(B , K , N , Cur_SNR , Cur_SNR , H)
        tic = tm.time()
        tmp_bers[0][i] =   eq2.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B}	)
        toc = tm.time()
        tmp_times[0][i] = toc - tic
        if i % 100 == 0:  
            eq2.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B})
            train_accuracy = accuracy.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B})
            print("test accuracy %g" % eq2.eval(feed_dict={NNinput: batch_Y, org_siganl: batch_X, batchSize: B}))
    bers[0][i_snr] = np.mean(tmp_bers[0])
    
    #medição constante do valor de ber
    
times[0][0] = np.mean(tmp_times[0])/B
print ('Average time to detect a single K bit signal is:')
print (times)
bers =  bers/(K*B)
bers = 1- bers
snrdb_list = np.linspace(low_snr_db_test,high_snr_db_test,num_snr)
print('snrdb_list')
print(snrdb_list)
print ('Bit error rates are is:')
print (bers)

#loop que mostra os valores obtidos para o usuário.
# Out:
# step 0, loss is 20218.2, number of correct bits 9952
# step 100, loss is 11638.4, number of correct bits 15784
# step 200, loss is 4822.45, number of correct bits 19213
# step 300, loss is 2769.78, number of correct bits 19785
# step 400, loss is 2679.04, number of correct bits 19813
# step 500, loss is 2621.79, number of correct bits 19836
# step 600, loss is 2564.53, number of correct bits 19837
# step 700, loss is 2536.71, number of correct bits 19821
# step 800, loss is 2497.58, number of correct bits 19823
# step 900, loss is 2444.1, number of correct bits 19805
# step 1000, loss is 2223.37, number of correct bits 19825
# step 1100, loss is 2086.04, number of correct bits 19837
# step 1200, loss is 2072.82, number of correct bits 19816
# step 1300, loss is 1898.11, number of correct bits 19814
# step 1400, loss is 1728.39, number of correct bits 19854
# step 1500, loss is 1655.74, number of correct bits 19834
# step 1600, loss is 1599.09, number of correct bits 19819
# step 1700, loss is 1424.05, number of correct bits 19860
# step 1800, loss is 1422.95, number of correct bits 19833
# step 1900, loss is 1341.25, number of correct bits 19849
# step 2000, loss is 1220.99, number of correct bits 19854
# step 2100, loss is 1220.47, number of correct bits 19812
# step 2200, loss is 1024.14, number of correct bits 19853
# step 2300, loss is 977.853, number of correct bits 19853
# step 2400, loss is 940.706, number of correct bits 19833
# step 2500, loss is 839.645, number of correct bits 19862
# step 2600, loss is 806.38, number of correct bits 19848
# step 2700, loss is 716.146, number of correct bits 19865
# step 2800, loss is 720.266, number of correct bits 19863
# step 2900, loss is 652.083, number of correct bits 19877
# step 3000, loss is 647.951, number of correct bits 19865
# step 3100, loss is 624.455, number of correct bits 19860
# step 3200, loss is 600.889, number of correct bits 19871
# step 3300, loss is 667.401, number of correct bits 19840
# step 3400, loss is 596.672, number of correct bits 19859
# step 3500, loss is 591.566, number of correct bits 19853
# step 3600, loss is 626.978, number of correct bits 19832
# step 3700, loss is 565.802, number of correct bits 19852
# step 3800, loss is 541.043, number of correct bits 19861
# step 3900, loss is 576.584, number of correct bits 19848
# step 4000, loss is 503.757, number of correct bits 19874
# step 4100, loss is 608.737, number of correct bits 19837
# step 4200, loss is 556.05, number of correct bits 19849
# step 4300, loss is 592.105, number of correct bits 19843
# step 4400, loss is 518.824, number of correct bits 19862
# step 4500, loss is 561.293, number of correct bits 19845
# step 4600, loss is 619.515, number of correct bits 19822
# step 4700, loss is 538.212, number of correct bits 19850
# step 4800, loss is 573.786, number of correct bits 19837
# step 4900, loss is 510.724, number of correct bits 19858
# step 5000, loss is 473.14, number of correct bits 19866
# step 5100, loss is 560.371, number of correct bits 19847
# step 5200, loss is 538.428, number of correct bits 19851
# step 5300, loss is 526.593, number of correct bits 19846
# step 5400, loss is 551.421, number of correct bits 19847
# step 5500, loss is 492.76, number of correct bits 19859
# step 5600, loss is 463.691, number of correct bits 19863
# step 5700, loss is 550.689, number of correct bits 19827
# step 5800, loss is 489.427, number of correct bits 19855
# step 5900, loss is 611.83, number of correct bits 19807
# step 6000, loss is 538.208, number of correct bits 19845
# step 6100, loss is 516.615, number of correct bits 19849
# step 6200, loss is 499.008, number of correct bits 19857
# step 6300, loss is 529.063, number of correct bits 19839
# step 6400, loss is 541.529, number of correct bits 19839
# step 6500, loss is 602.194, number of correct bits 19815
# step 6600, loss is 491.493, number of correct bits 19849
# step 6700, loss is 551.01, number of correct bits 19833
# step 6800, loss is 451.237, number of correct bits 19863
# step 6900, loss is 566.383, number of correct bits 19833
# step 7000, loss is 517.861, number of correct bits 19851
# step 7100, loss is 513.274, number of correct bits 19849
# step 7200, loss is 557.438, number of correct bits 19836
# step 7300, loss is 544.407, number of correct bits 19843
# step 7400, loss is 422.841, number of correct bits 19882
# step 7500, loss is 490.681, number of correct bits 19844
# step 7600, loss is 531.952, number of correct bits 19844
# step 7700, loss is 555.057, number of correct bits 19827
# step 7800, loss is 543.577, number of correct bits 19823
# step 7900, loss is 519.861, number of correct bits 19842
# step 8000, loss is 474.637, number of correct bits 19866
# step 8100, loss is 506.267, number of correct bits 19859
# step 8200, loss is 498.471, number of correct bits 19837
# step 8300, loss is 446.654, number of correct bits 19856
# step 8400, loss is 531.989, number of correct bits 19848
# step 8500, loss is 538.922, number of correct bits 19842
# step 8600, loss is 519.926, number of correct bits 19841
# step 8700, loss is 482.172, number of correct bits 19861
# step 8800, loss is 476.145, number of correct bits 19866
# step 8900, loss is 519.629, number of correct bits 19844
# step 9000, loss is 548.199, number of correct bits 19829
# step 9100, loss is 524.166, number of correct bits 19843
# step 9200, loss is 494.923, number of correct bits 19855
# step 9300, loss is 522.76, number of correct bits 19844
# step 9400, loss is 528.873, number of correct bits 19843
# step 9500, loss is 458.69, number of correct bits 19863
# step 9600, loss is 488.33, number of correct bits 19856
# step 9700, loss is 544.532, number of correct bits 19834
# step 9800, loss is 517.412, number of correct bits 19842
# step 9900, loss is 517.405, number of correct bits 19838
# step 10000, loss is 437.682, number of correct bits 19872
# step 10100, loss is 518.889, number of correct bits 19849
# step 10200, loss is 490.508, number of correct bits 19849
# step 10300, loss is 512.593, number of correct bits 19845
# step 10400, loss is 486.496, number of correct bits 19860
# step 10500, loss is 464.203, number of correct bits 19861
# step 10600, loss is 505.769, number of correct bits 19847
# step 10700, loss is 512.681, number of correct bits 19845
# step 10800, loss is 549.74, number of correct bits 19836
# step 10900, loss is 549.058, number of correct bits 19830
# step 11000, loss is 553.384, number of correct bits 19833
# step 11100, loss is 488.3, number of correct bits 19850
# step 11200, loss is 465.8, number of correct bits 19859
# step 11300, loss is 469.065, number of correct bits 19856
# step 11400, loss is 451.862, number of correct bits 19861
# step 11500, loss is 536.165, number of correct bits 19840
# step 11600, loss is 572.247, number of correct bits 19817
# step 11700, loss is 520.759, number of correct bits 19839
# step 11800, loss is 511.732, number of correct bits 19844
# step 11900, loss is 452.885, number of correct bits 19870
# step 12000, loss is 522.167, number of correct bits 19843
# step 12100, loss is 532.741, number of correct bits 19826
# step 12200, loss is 534.165, number of correct bits 19827
# step 12300, loss is 483.157, number of correct bits 19852
# step 12400, loss is 465.064, number of correct bits 19860
# step 12500, loss is 549.009, number of correct bits 19834
# step 12600, loss is 461.937, number of correct bits 19873
# step 12700, loss is 556.841, number of correct bits 19837
# step 12800, loss is 586.442, number of correct bits 19817
# step 12900, loss is 508.057, number of correct bits 19841
# step 13000, loss is 526.798, number of correct bits 19843
# step 13100, loss is 485.415, number of correct bits 19852
# step 13200, loss is 498.336, number of correct bits 19842
# step 13300, loss is 462.649, number of correct bits 19857
# step 13400, loss is 493.369, number of correct bits 19840
# step 13500, loss is 562.675, number of correct bits 19815
# step 13600, loss is 537.405, number of correct bits 19822
# step 13700, loss is 408.807, number of correct bits 19887
# step 13800, loss is 481.966, number of correct bits 19845
# step 13900, loss is 459.417, number of correct bits 19863
# step 14000, loss is 455.364, number of correct bits 19878
# step 14100, loss is 477.87, number of correct bits 19857
# step 14200, loss is 492.704, number of correct bits 19849
# step 14300, loss is 527.46, number of correct bits 19835
# step 14400, loss is 412.552, number of correct bits 19887
# step 14500, loss is 514.345, number of correct bits 19833
# step 14600, loss is 465.027, number of correct bits 19860
# step 14700, loss is 496.989, number of correct bits 19854
# step 14800, loss is 514.938, number of correct bits 19845
# step 14900, loss is 489.498, number of correct bits 19847
# step 15000, loss is 585.356, number of correct bits 19824
# step 15100, loss is 534.44, number of correct bits 19833
# step 15200, loss is 511.495, number of correct bits 19839
# step 15300, loss is 456.659, number of correct bits 19854
# step 15400, loss is 453.16, number of correct bits 19860
# step 15500, loss is 562.533, number of correct bits 19811
# step 15600, loss is 457.697, number of correct bits 19853
# step 15700, loss is 487.885, number of correct bits 19856
# step 15800, loss is 469.79, number of correct bits 19860
# step 15900, loss is 471.433, number of correct bits 19857
# step 16000, loss is 498.238, number of correct bits 19856
# step 16100, loss is 456.388, number of correct bits 19862
# step 16200, loss is 458.378, number of correct bits 19872
# step 16300, loss is 474.712, number of correct bits 19855
# step 16400, loss is 493.798, number of correct bits 19848
# step 16500, loss is 516.222, number of correct bits 19841
# step 16600, loss is 540.928, number of correct bits 19839
# step 16700, loss is 494.547, number of correct bits 19857
# step 16800, loss is 485.488, number of correct bits 19856
# step 16900, loss is 459.856, number of correct bits 19861
# step 17000, loss is 455.085, number of correct bits 19863
# step 17100, loss is 533.819, number of correct bits 19833
# step 17200, loss is 420.603, number of correct bits 19878
# step 17300, loss is 486.594, number of correct bits 19859
# step 17400, loss is 495.042, number of correct bits 19854
# step 17500, loss is 487.449, number of correct bits 19860
# step 17600, loss is 595.816, number of correct bits 19828
# step 17700, loss is 528.667, number of correct bits 19828
# step 17800, loss is 558.886, number of correct bits 19829
# step 17900, loss is 471.312, number of correct bits 19850
# step 18000, loss is 487.848, number of correct bits 19857
# step 18100, loss is 462.628, number of correct bits 19863
# step 18200, loss is 515.474, number of correct bits 19837
# step 18300, loss is 471.756, number of correct bits 19863
# step 18400, loss is 514.141, number of correct bits 19838
# step 18500, loss is 472.819, number of correct bits 19864
# step 18600, loss is 529.383, number of correct bits 19847
# step 18700, loss is 406.954, number of correct bits 19886
# step 18800, loss is 498.347, number of correct bits 19850
# step 18900, loss is 403.001, number of correct bits 19881
# step 19000, loss is 452.446, number of correct bits 19862
# step 19100, loss is 419.929, number of correct bits 19865
# step 19200, loss is 541.341, number of correct bits 19841
# step 19300, loss is 446.742, number of correct bits 19868
# step 19400, loss is 510.443, number of correct bits 19850
# step 19500, loss is 543.766, number of correct bits 19837
# step 19600, loss is 473.257, number of correct bits 19853
# step 19700, loss is 517.141, number of correct bits 19842
# step 19800, loss is 499.049, number of correct bits 19846
# step 19900, loss is 502.241, number of correct bits 19839
# step 20000, loss is 537.227, number of correct bits 19834
# step 20100, loss is 499.58, number of correct bits 19851
# step 20200, loss is 498.793, number of correct bits 19842
# step 20300, loss is 518.188, number of correct bits 19842
# step 20400, loss is 444.346, number of correct bits 19867
# step 20500, loss is 540.822, number of correct bits 19823
# step 20600, loss is 547.897, number of correct bits 19833
# step 20700, loss is 550.409, number of correct bits 19821
# step 20800, loss is 514.27, number of correct bits 19841
# step 20900, loss is 468.127, number of correct bits 19855
# step 21000, loss is 509.181, number of correct bits 19848
# step 21100, loss is 507.583, number of correct bits 19838
# step 21200, loss is 543.534, number of correct bits 19830
# step 21300, loss is 507.918, number of correct bits 19843
# step 21400, loss is 471.378, number of correct bits 19855
# step 21500, loss is 501.417, number of correct bits 19849
# step 21600, loss is 491.527, number of correct bits 19855
# step 21700, loss is 458.818, number of correct bits 19870
# step 21800, loss is 458.969, number of correct bits 19873
# step 21900, loss is 460.035, number of correct bits 19864
# step 22000, loss is 445.468, number of correct bits 19869
# step 22100, loss is 464.901, number of correct bits 19861
# step 22200, loss is 415.688, number of correct bits 19881
# step 22300, loss is 488.237, number of correct bits 19857
# step 22400, loss is 460.377, number of correct bits 19856
# step 22500, loss is 438.611, number of correct bits 19866
# step 22600, loss is 481.084, number of correct bits 19851
# step 22700, loss is 473.764, number of correct bits 19863
# step 22800, loss is 515.823, number of correct bits 19836
# step 22900, loss is 494.496, number of correct bits 19858
# step 23000, loss is 529.096, number of correct bits 19842
# step 23100, loss is 497.787, number of correct bits 19849
# step 23200, loss is 456.035, number of correct bits 19863
# step 23300, loss is 484.072, number of correct bits 19854
# step 23400, loss is 459.559, number of correct bits 19857
# step 23500, loss is 411.017, number of correct bits 19878
# step 23600, loss is 494.368, number of correct bits 19854
# step 23700, loss is 499.796, number of correct bits 19848
# step 23800, loss is 504.024, number of correct bits 19849
# step 23900, loss is 487.833, number of correct bits 19850
# step 24000, loss is 437.546, number of correct bits 19868
# step 24100, loss is 518.539, number of correct bits 19840
# step 24200, loss is 519.847, number of correct bits 19845
# step 24300, loss is 470.609, number of correct bits 19855
# step 24400, loss is 503.949, number of correct bits 19839
# step 24500, loss is 448.676, number of correct bits 19856
# step 24600, loss is 495.348, number of correct bits 19851
# step 24700, loss is 464.867, number of correct bits 19857
# step 24800, loss is 440.529, number of correct bits 19863
# step 24900, loss is 474.992, number of correct bits 19845
# step 25000, loss is 528.499, number of correct bits 19829
# step 25100, loss is 501.34, number of correct bits 19845
# step 25200, loss is 554.569, number of correct bits 19818
# step 25300, loss is 446.544, number of correct bits 19870
# step 25400, loss is 515.774, number of correct bits 19840
# step 25500, loss is 424.415, number of correct bits 19867
# step 25600, loss is 508.624, number of correct bits 19848
# step 25700, loss is 455.221, number of correct bits 19853
# step 25800, loss is 478.575, number of correct bits 19845
# step 25900, loss is 440.115, number of correct bits 19870
# step 26000, loss is 491.035, number of correct bits 19854
# step 26100, loss is 510.462, number of correct bits 19848
# step 26200, loss is 417.368, number of correct bits 19880
# step 26300, loss is 488.172, number of correct bits 19848
# step 26400, loss is 489.498, number of correct bits 19852
# step 26500, loss is 397.442, number of correct bits 19882
# step 26600, loss is 421.141, number of correct bits 19875
# step 26700, loss is 466.806, number of correct bits 19851
# step 26800, loss is 489.915, number of correct bits 19851
# step 26900, loss is 488.201, number of correct bits 19855
# step 27000, loss is 466.656, number of correct bits 19859
# step 27100, loss is 447.18, number of correct bits 19864
# step 27200, loss is 420.345, number of correct bits 19876
# step 27300, loss is 525.458, number of correct bits 19844
# step 27400, loss is 475.37, number of correct bits 19857
# step 27500, loss is 415.083, number of correct bits 19873
# step 27600, loss is 510.995, number of correct bits 19846
# step 27700, loss is 418.673, number of correct bits 19869
# step 27800, loss is 489.631, number of correct bits 19855
# step 27900, loss is 475.732, number of correct bits 19851
# step 28000, loss is 423.177, number of correct bits 19863
# step 28100, loss is 451.516, number of correct bits 19856
# step 28200, loss is 512.125, number of correct bits 19851
# step 28300, loss is 438.185, number of correct bits 19869
# step 28400, loss is 423.605, number of correct bits 19881
# step 28500, loss is 442.57, number of correct bits 19859
# step 28600, loss is 538.392, number of correct bits 19839
# step 28700, loss is 393.619, number of correct bits 19891
# step 28800, loss is 427.61, number of correct bits 19878
# step 28900, loss is 466.521, number of correct bits 19862
# step 29000, loss is 534.713, number of correct bits 19838
# step 29100, loss is 450.225, number of correct bits 19866
# step 29200, loss is 503.715, number of correct bits 19843
# step 29300, loss is 431.8, number of correct bits 19860
# step 29400, loss is 430.662, number of correct bits 19872
# step 29500, loss is 450.297, number of correct bits 19863
# step 29600, loss is 491.934, number of correct bits 19854
# step 29700, loss is 418.31, number of correct bits 19879
# step 29800, loss is 449.861, number of correct bits 19866
# step 29900, loss is 405.98, number of correct bits 19879
# step 30000, loss is 517.381, number of correct bits 19836
# step 30100, loss is 460.881, number of correct bits 19859
# step 30200, loss is 443.634, number of correct bits 19858
# step 30300, loss is 462.552, number of correct bits 19859
# step 30400, loss is 448.573, number of correct bits 19854
# step 30500, loss is 461.316, number of correct bits 19865
# step 30600, loss is 432.068, number of correct bits 19870
# step 30700, loss is 450.744, number of correct bits 19864
# step 30800, loss is 493.012, number of correct bits 19856
# step 30900, loss is 500.216, number of correct bits 19858
# step 31000, loss is 495.824, number of correct bits 19853
# step 31100, loss is 454.377, number of correct bits 19866
# step 31200, loss is 434.159, number of correct bits 19870
# step 31300, loss is 468.582, number of correct bits 19860
# step 31400, loss is 435.499, number of correct bits 19873
# step 31500, loss is 384.346, number of correct bits 19876
# step 31600, loss is 469.054, number of correct bits 19861
# step 31700, loss is 362.238, number of correct bits 19887
# step 31800, loss is 484.801, number of correct bits 19856
# step 31900, loss is 420.014, number of correct bits 19881
# step 32000, loss is 412.077, number of correct bits 19878
# step 32100, loss is 424.844, number of correct bits 19871
# step 32200, loss is 423.354, number of correct bits 19877
# step 32300, loss is 480.219, number of correct bits 19862
# step 32400, loss is 479.823, number of correct bits 19866
# step 32500, loss is 431.758, number of correct bits 19873
# step 32600, loss is 504.019, number of correct bits 19851
# step 32700, loss is 454.176, number of correct bits 19868
# step 32800, loss is 471.111, number of correct bits 19856
# step 32900, loss is 397.001, number of correct bits 19889
# step 33000, loss is 444.197, number of correct bits 19868
# step 33100, loss is 443.678, number of correct bits 19868
# step 33200, loss is 422.431, number of correct bits 19880
# step 33300, loss is 441.226, number of correct bits 19871
# step 33400, loss is 424.245, number of correct bits 19864
# step 33500, loss is 486.342, number of correct bits 19850
# step 33600, loss is 427.983, number of correct bits 19872
# step 33700, loss is 458.32, number of correct bits 19858
# step 33800, loss is 432.585, number of correct bits 19873
# step 33900, loss is 447.865, number of correct bits 19867
# step 34000, loss is 443.549, number of correct bits 19864
# step 34100, loss is 439.788, number of correct bits 19875
# step 34200, loss is 356.583, number of correct bits 19902
# step 34300, loss is 486.188, number of correct bits 19845
# step 34400, loss is 431.362, number of correct bits 19877
# step 34500, loss is 431.474, number of correct bits 19871
# step 34600, loss is 399.133, number of correct bits 19879
# step 34700, loss is 395.754, number of correct bits 19885
# step 34800, loss is 406.43, number of correct bits 19886
# step 34900, loss is 513.462, number of correct bits 19846
# step 35000, loss is 423.867, number of correct bits 19879
# step 35100, loss is 456.534, number of correct bits 19863
# step 35200, loss is 382.056, number of correct bits 19889
# step 35300, loss is 407.28, number of correct bits 19872
# step 35400, loss is 463.573, number of correct bits 19862
# step 35500, loss is 467.772, number of correct bits 19864
# step 35600, loss is 444.563, number of correct bits 19874
# step 35700, loss is 467.192, number of correct bits 19869
# step 35800, loss is 389.376, number of correct bits 19885
# step 35900, loss is 461.699, number of correct bits 19853
# step 36000, loss is 420.398, number of correct bits 19876
# step 36100, loss is 409.631, number of correct bits 19873
# step 36200, loss is 475.51, number of correct bits 19865
# step 36300, loss is 351.049, number of correct bits 19899
# step 36400, loss is 521.27, number of correct bits 19843
# step 36500, loss is 382.815, number of correct bits 19893
# step 36600, loss is 456.007, number of correct bits 19866
# step 36700, loss is 440.566, number of correct bits 19872
# step 36800, loss is 399.745, number of correct bits 19877
# step 36900, loss is 425.764, number of correct bits 19875
# step 37000, loss is 327.626, number of correct bits 19900
# step 37100, loss is 470.377, number of correct bits 19858
# step 37200, loss is 382.319, number of correct bits 19887
# step 37300, loss is 500.524, number of correct bits 19848
# step 37400, loss is 423.024, number of correct bits 19876
# step 37500, loss is 403.157, number of correct bits 19874
# step 37600, loss is 375.435, number of correct bits 19894
# step 37700, loss is 451.266, number of correct bits 19869
# step 37800, loss is 412.683, number of correct bits 19887
# step 37900, loss is 392.06, number of correct bits 19881
# step 38000, loss is 427.933, number of correct bits 19884
# step 38100, loss is 458.368, number of correct bits 19867
# step 38200, loss is 386.215, number of correct bits 19884
# step 38300, loss is 373.244, number of correct bits 19891
# step 38400, loss is 448.983, number of correct bits 19869
# step 38500, loss is 399.183, number of correct bits 19882
# step 38600, loss is 484.999, number of correct bits 19857
# step 38700, loss is 366.077, number of correct bits 19891
# step 38800, loss is 449.4, number of correct bits 19868
# step 38900, loss is 470.194, number of correct bits 19864
# step 39000, loss is 410.734, number of correct bits 19878
# step 39100, loss is 345.505, number of correct bits 19892
# step 39200, loss is 387.624, number of correct bits 19893
# step 39300, loss is 398.339, number of correct bits 19881
# step 39400, loss is 419.49, number of correct bits 19890
# step 39500, loss is 398.2, number of correct bits 19883
# step 39600, loss is 451.551, number of correct bits 19864
# step 39700, loss is 475.453, number of correct bits 19851
# step 39800, loss is 424.05, number of correct bits 19885
# step 39900, loss is 436.513, number of correct bits 19869
# step 40000, loss is 390.267, number of correct bits 19894
# step 40100, loss is 474.33, number of correct bits 19856
# step 40200, loss is 412.188, number of correct bits 19873
# step 40300, loss is 438.372, number of correct bits 19864
# step 40400, loss is 450.37, number of correct bits 19862
# step 40500, loss is 418.962, number of correct bits 19880
# step 40600, loss is 436.578, number of correct bits 19874
# step 40700, loss is 476.355, number of correct bits 19868
# step 40800, loss is 424.288, number of correct bits 19874
# step 40900, loss is 391.454, number of correct bits 19888
# step 41000, loss is 417.101, number of correct bits 19888
# step 41100, loss is 407.175, number of correct bits 19880
# step 41200, loss is 412.407, number of correct bits 19883
# step 41300, loss is 445.804, number of correct bits 19861
# step 41400, loss is 362.449, number of correct bits 19885
# step 41500, loss is 467.379, number of correct bits 19865
# step 41600, loss is 455.838, number of correct bits 19865
# step 41700, loss is 419.565, number of correct bits 19870
# step 41800, loss is 371.28, number of correct bits 19890
# step 41900, loss is 441.299, number of correct bits 19862
# step 42000, loss is 421.983, number of correct bits 19869
# step 42100, loss is 400.851, number of correct bits 19886
# step 42200, loss is 395.076, number of correct bits 19885
# step 42300, loss is 479.505, number of correct bits 19862
# step 42400, loss is 365.236, number of correct bits 19895
# step 42500, loss is 407.989, number of correct bits 19872
# step 42600, loss is 459.964, number of correct bits 19859
# step 42700, loss is 426.181, number of correct bits 19871
# step 42800, loss is 450.828, number of correct bits 19853
# step 42900, loss is 453.889, number of correct bits 19866
# step 43000, loss is 416.715, number of correct bits 19875
# step 43100, loss is 388.946, number of correct bits 19890
# step 43200, loss is 397.519, number of correct bits 19875
# step 43300, loss is 453.949, number of correct bits 19866
# step 43400, loss is 461.896, number of correct bits 19863
# step 43500, loss is 447.636, number of correct bits 19851
# step 43600, loss is 381.102, number of correct bits 19888
# step 43700, loss is 366.139, number of correct bits 19897
# step 43800, loss is 417.022, number of correct bits 19873
# step 43900, loss is 385.992, number of correct bits 19889
# step 44000, loss is 396.253, number of correct bits 19878
# step 44100, loss is 397.771, number of correct bits 19884
# step 44200, loss is 470.879, number of correct bits 19862
# step 44300, loss is 419.719, number of correct bits 19881
# step 44400, loss is 396.064, number of correct bits 19893
# step 44500, loss is 414.73, number of correct bits 19876
# step 44600, loss is 403.138, number of correct bits 19879
# step 44700, loss is 364.404, number of correct bits 19898
# step 44800, loss is 339.472, number of correct bits 19906
# step 44900, loss is 428.807, number of correct bits 19876
# step 45000, loss is 421.838, number of correct bits 19873
# step 45100, loss is 400.301, number of correct bits 19885
# step 45200, loss is 425.513, number of correct bits 19874
# step 45300, loss is 350.343, number of correct bits 19907
# step 45400, loss is 469.523, number of correct bits 19868
# step 45500, loss is 414.307, number of correct bits 19877
# step 45600, loss is 360.693, number of correct bits 19898
# step 45700, loss is 481.776, number of correct bits 19847
# step 45800, loss is 374.994, number of correct bits 19894
# step 45900, loss is 489.505, number of correct bits 19847
# step 46000, loss is 349.142, number of correct bits 19902
# step 46100, loss is 438.275, number of correct bits 19864
# step 46200, loss is 373.935, number of correct bits 19891
# step 46300, loss is 402.579, number of correct bits 19879
# step 46400, loss is 396.917, number of correct bits 19880
# step 46500, loss is 342.466, number of correct bits 19897
# step 46600, loss is 397.536, number of correct bits 19881
# step 46700, loss is 382.1, number of correct bits 19890
# step 46800, loss is 456.442, number of correct bits 19866
# step 46900, loss is 415.441, number of correct bits 19876
# step 47000, loss is 392.495, number of correct bits 19872
# step 47100, loss is 414.28, number of correct bits 19886
# step 47200, loss is 467.334, number of correct bits 19853
# step 47300, loss is 411.257, number of correct bits 19870
# step 47400, loss is 441.621, number of correct bits 19868
# step 47500, loss is 381.622, number of correct bits 19892
# step 47600, loss is 408.949, number of correct bits 19873
# step 47700, loss is 317.582, number of correct bits 19910
# step 47800, loss is 347.454, number of correct bits 19900
# step 47900, loss is 422.319, number of correct bits 19865
# step 48000, loss is 423.666, number of correct bits 19873
# step 48100, loss is 400.739, number of correct bits 19868
# step 48200, loss is 371.529, number of correct bits 19886
# step 48300, loss is 402.63, number of correct bits 19881
# step 48400, loss is 389.187, number of correct bits 19883
# step 48500, loss is 370.421, number of correct bits 19889
# step 48600, loss is 477.767, number of correct bits 19849
# step 48700, loss is 327.906, number of correct bits 19904
# step 48800, loss is 407.363, number of correct bits 19878
# step 48900, loss is 398.363, number of correct bits 19876
# step 49000, loss is 413.155, number of correct bits 19872
# step 49100, loss is 407.305, number of correct bits 19881
# step 49200, loss is 400.189, number of correct bits 19877
# step 49300, loss is 398.012, number of correct bits 19895
# step 49400, loss is 349.459, number of correct bits 19891
# step 49500, loss is 410.914, number of correct bits 19876
# step 49600, loss is 428.99, number of correct bits 19866
# step 49700, loss is 382.409, number of correct bits 19894
# step 49800, loss is 448.982, number of correct bits 19869
# step 49900, loss is 403.807, number of correct bits 19881
# step 50000, loss is 413.77, number of correct bits 19878
# step 50100, loss is 331.208, number of correct bits 19909
# step 50200, loss is 454.389, number of correct bits 19862
# step 50300, loss is 452.195, number of correct bits 19856
# step 50400, loss is 400.324, number of correct bits 19890
# step 50500, loss is 355.652, number of correct bits 19897
# step 50600, loss is 414.732, number of correct bits 19881
# step 50700, loss is 361.391, number of correct bits 19895
# step 50800, loss is 390.325, number of correct bits 19891
# step 50900, loss is 384.954, number of correct bits 19888
# step 51000, loss is 452.94, number of correct bits 19861
# step 51100, loss is 384.415, number of correct bits 19880
# step 51200, loss is 493.752, number of correct bits 19846
# step 51300, loss is 393.454, number of correct bits 19878
# step 51400, loss is 428.935, number of correct bits 19871
# step 51500, loss is 411.771, number of correct bits 19869
# step 51600, loss is 403.83, number of correct bits 19871
# step 51700, loss is 401.647, number of correct bits 19884
# step 51800, loss is 424.851, number of correct bits 19865
# step 51900, loss is 362.379, number of correct bits 19894
# step 52000, loss is 415.761, number of correct bits 19881
# step 52100, loss is 370.241, number of correct bits 19902
# step 52200, loss is 419.731, number of correct bits 19871
# step 52300, loss is 370.959, number of correct bits 19882
# step 52400, loss is 379.334, number of correct bits 19886
# step 52500, loss is 340.663, number of correct bits 19901
# step 52600, loss is 348.949, number of correct bits 19903
# step 52700, loss is 456.025, number of correct bits 19858
# step 52800, loss is 333.786, number of correct bits 19912
# step 52900, loss is 379.25, number of correct bits 19888
# step 53000, loss is 351.033, number of correct bits 19902
# step 53100, loss is 461.926, number of correct bits 19863
# step 53200, loss is 403.642, number of correct bits 19881
# step 53300, loss is 298.845, number of correct bits 19913
# step 53400, loss is 389.453, number of correct bits 19888
# step 53500, loss is 374.183, number of correct bits 19888
# step 53600, loss is 382.036, number of correct bits 19901
# step 53700, loss is 428.95, number of correct bits 19871
# step 53800, loss is 429.3, number of correct bits 19871
# step 53900, loss is 381.071, number of correct bits 19895
# step 54000, loss is 381.894, number of correct bits 19890
# step 54100, loss is 462.258, number of correct bits 19859
# step 54200, loss is 339.478, number of correct bits 19911
# step 54300, loss is 423.912, number of correct bits 19870
# step 54400, loss is 468.435, number of correct bits 19863
# step 54500, loss is 360.46, number of correct bits 19895
# step 54600, loss is 370.223, number of correct bits 19898
# step 54700, loss is 380.425, number of correct bits 19887
# step 54800, loss is 422.794, number of correct bits 19873
# step 54900, loss is 382.239, number of correct bits 19896
# step 55000, loss is 361.428, number of correct bits 19900
# step 55100, loss is 405.443, number of correct bits 19876
# step 55200, loss is 369.191, number of correct bits 19887
# step 55300, loss is 340.305, number of correct bits 19904
# step 55400, loss is 402.204, number of correct bits 19883
# step 55500, loss is 353.329, number of correct bits 19896
# step 55600, loss is 417.558, number of correct bits 19873
# step 55700, loss is 405.844, number of correct bits 19872
# step 55800, loss is 412.673, number of correct bits 19881
# step 55900, loss is 391.607, number of correct bits 19884
# step 56000, loss is 379.255, number of correct bits 19894
# step 56100, loss is 351.562, number of correct bits 19894
# step 56200, loss is 393.403, number of correct bits 19877
# step 56300, loss is 429.872, number of correct bits 19874
# step 56400, loss is 402.037, number of correct bits 19877
# step 56500, loss is 455.411, number of correct bits 19871
# step 56600, loss is 343.439, number of correct bits 19891
# step 56700, loss is 452.786, number of correct bits 19866
# step 56800, loss is 456.861, number of correct bits 19858
# step 56900, loss is 380.52, number of correct bits 19902
# step 57000, loss is 374.806, number of correct bits 19897
# step 57100, loss is 375.463, number of correct bits 19890
# step 57200, loss is 369.473, number of correct bits 19892
# step 57300, loss is 399.101, number of correct bits 19879
# step 57400, loss is 439.982, number of correct bits 19873
# step 57500, loss is 413.417, number of correct bits 19880
# step 57600, loss is 419.282, number of correct bits 19872
# step 57700, loss is 371.489, number of correct bits 19887
# step 57800, loss is 431.317, number of correct bits 19866
# step 57900, loss is 395.336, number of correct bits 19883
# step 58000, loss is 373.861, number of correct bits 19897
# step 58100, loss is 421.363, number of correct bits 19881
# step 58200, loss is 399.505, number of correct bits 19894
# step 58300, loss is 382.948, number of correct bits 19890
# step 58400, loss is 361.153, number of correct bits 19897
# step 58500, loss is 381.523, number of correct bits 19896
# step 58600, loss is 379.214, number of correct bits 19888
# step 58700, loss is 360.044, number of correct bits 19895
# step 58800, loss is 386.803, number of correct bits 19889
# step 58900, loss is 473.978, number of correct bits 19857
# step 59000, loss is 449.362, number of correct bits 19865
# step 59100, loss is 375.363, number of correct bits 19894
# step 59200, loss is 356.184, number of correct bits 19899
# step 59300, loss is 437.753, number of correct bits 19874
# step 59400, loss is 431.469, number of correct bits 19867
# step 59500, loss is 404.827, number of correct bits 19874
# step 59600, loss is 443.792, number of correct bits 19855
# step 59700, loss is 424.643, number of correct bits 19874
# step 59800, loss is 421.24, number of correct bits 19881
# step 59900, loss is 416.531, number of correct bits 19888
# step 60000, loss is 355.891, number of correct bits 19905
# step 60100, loss is 393.824, number of correct bits 19890
# step 60200, loss is 345.725, number of correct bits 19895
# step 60300, loss is 342.374, number of correct bits 19899
# step 60400, loss is 328.57, number of correct bits 19915
# step 60500, loss is 353.732, number of correct bits 19907
# step 60600, loss is 342.948, number of correct bits 19902
# step 60700, loss is 353.406, number of correct bits 19897
# step 60800, loss is 405.156, number of correct bits 19873
# step 60900, loss is 419.02, number of correct bits 19871
# step 61000, loss is 383.354, number of correct bits 19889
# step 61100, loss is 387.049, number of correct bits 19895
# step 61200, loss is 435.702, number of correct bits 19863
# step 61300, loss is 332.218, number of correct bits 19907
# step 61400, loss is 377.544, number of correct bits 19893
# step 61500, loss is 464.825, number of correct bits 19864
# step 61600, loss is 326.413, number of correct bits 19910
# step 61700, loss is 369.634, number of correct bits 19885
# step 61800, loss is 378.057, number of correct bits 19892
# step 61900, loss is 326.707, number of correct bits 19912
# step 62000, loss is 363.307, number of correct bits 19896
# step 62100, loss is 357.391, number of correct bits 19897
# step 62200, loss is 370.272, number of correct bits 19890
# step 62300, loss is 328.962, number of correct bits 19902
# step 62400, loss is 362.566, number of correct bits 19898
# step 62500, loss is 399.594, number of correct bits 19888
# step 62600, loss is 356.306, number of correct bits 19896
# step 62700, loss is 381.926, number of correct bits 19891
# step 62800, loss is 362.798, number of correct bits 19892
# step 62900, loss is 385.89, number of correct bits 19889
# step 63000, loss is 395.117, number of correct bits 19886
# step 63100, loss is 433.709, number of correct bits 19878
# step 63200, loss is 345.127, number of correct bits 19901
# step 63300, loss is 331.339, number of correct bits 19908
# step 63400, loss is 411.847, number of correct bits 19883
# step 63500, loss is 373.147, number of correct bits 19890
# step 63600, loss is 386.852, number of correct bits 19881
# step 63700, loss is 411.321, number of correct bits 19875
# step 63800, loss is 373.073, number of correct bits 19895
# step 63900, loss is 335.031, number of correct bits 19901
# step 64000, loss is 452.873, number of correct bits 19872
# step 64100, loss is 427.697, number of correct bits 19876
# step 64200, loss is 389.846, number of correct bits 19895
# step 64300, loss is 297.056, number of correct bits 19921
# step 64400, loss is 354.479, number of correct bits 19897
# step 64500, loss is 355.547, number of correct bits 19899
# step 64600, loss is 400.639, number of correct bits 19878
# step 64700, loss is 395.358, number of correct bits 19874
# step 64800, loss is 400.081, number of correct bits 19883
# step 64900, loss is 403.709, number of correct bits 19884
# step 65000, loss is 391.877, number of correct bits 19882
# step 65100, loss is 324.007, number of correct bits 19912
# step 65200, loss is 385.448, number of correct bits 19888
# step 65300, loss is 334.294, number of correct bits 19907
# step 65400, loss is 387.027, number of correct bits 19893
# step 65500, loss is 342.553, number of correct bits 19893
# step 65600, loss is 382.353, number of correct bits 19890
# step 65700, loss is 308.62, number of correct bits 19912
# step 65800, loss is 377.447, number of correct bits 19889
# step 65900, loss is 318.057, number of correct bits 19916
# step 66000, loss is 399.446, number of correct bits 19878
# step 66100, loss is 388.468, number of correct bits 19882
# step 66200, loss is 372.346, number of correct bits 19888
# step 66300, loss is 344.053, number of correct bits 19902
# step 66400, loss is 376.728, number of correct bits 19897
# step 66500, loss is 417.288, number of correct bits 19868
# step 66600, loss is 330.488, number of correct bits 19917
# step 66700, loss is 384.35, number of correct bits 19888
# step 66800, loss is 382.85, number of correct bits 19874
# step 66900, loss is 397.863, number of correct bits 19885
# step 67000, loss is 394.148, number of correct bits 19889
# step 67100, loss is 405.695, number of correct bits 19878
# step 67200, loss is 377.963, number of correct bits 19894
# step 67300, loss is 356.379, number of correct bits 19897
# step 67400, loss is 410.133, number of correct bits 19884
# step 67500, loss is 337.523, number of correct bits 19897
# step 67600, loss is 315.769, number of correct bits 19911
# step 67700, loss is 405.718, number of correct bits 19877
# step 67800, loss is 365.784, number of correct bits 19892
# step 67900, loss is 368.658, number of correct bits 19885
# step 68000, loss is 348.402, number of correct bits 19902
# step 68100, loss is 383.883, number of correct bits 19889
# step 68200, loss is 325.661, number of correct bits 19907
# step 68300, loss is 398.371, number of correct bits 19882
# step 68400, loss is 369.705, number of correct bits 19894
# step 68500, loss is 385.351, number of correct bits 19886
# step 68600, loss is 405.697, number of correct bits 19880
# step 68700, loss is 319.4, number of correct bits 19909
# step 68800, loss is 373.873, number of correct bits 19896
# step 68900, loss is 426.271, number of correct bits 19870
# step 69000, loss is 363.856, number of correct bits 19896
# step 69100, loss is 459.143, number of correct bits 19861
# step 69200, loss is 403.423, number of correct bits 19885
# step 69300, loss is 375.668, number of correct bits 19889
# step 69400, loss is 392.434, number of correct bits 19883
# step 69500, loss is 378.331, number of correct bits 19889
# step 69600, loss is 349.558, number of correct bits 19893
# step 69700, loss is 413.259, number of correct bits 19867
# step 69800, loss is 393.759, number of correct bits 19870
# step 69900, loss is 387.845, number of correct bits 19883
# step 70000, loss is 423.889, number of correct bits 19872
# step 70100, loss is 307.992, number of correct bits 19913
# step 70200, loss is 390.261, number of correct bits 19884
# step 70300, loss is 350.065, number of correct bits 19901
# step 70400, loss is 360.333, number of correct bits 19887
# step 70500, loss is 405.136, number of correct bits 19890
# step 70600, loss is 325.304, number of correct bits 19905
# step 70700, loss is 390.391, number of correct bits 19891
# step 70800, loss is 446.351, number of correct bits 19870
# step 70900, loss is 373.169, number of correct bits 19892
# step 71000, loss is 395.233, number of correct bits 19883
# step 71100, loss is 464.631, number of correct bits 19853
# step 71200, loss is 337.041, number of correct bits 19902
# step 71300, loss is 319.62, number of correct bits 19914
# step 71400, loss is 466.39, number of correct bits 19851
# step 71500, loss is 344.492, number of correct bits 19894
# step 71600, loss is 367.348, number of correct bits 19889
# step 71700, loss is 410.012, number of correct bits 19882
# step 71800, loss is 364.15, number of correct bits 19896
# step 71900, loss is 356.713, number of correct bits 19894
# step 72000, loss is 319.41, number of correct bits 19915
# step 72100, loss is 364.636, number of correct bits 19887
# step 72200, loss is 339.587, number of correct bits 19901
# step 72300, loss is 367.839, number of correct bits 19891
# step 72400, loss is 389.636, number of correct bits 19887
# step 72500, loss is 386.164, number of correct bits 19882
# step 72600, loss is 405.521, number of correct bits 19880
# step 72700, loss is 409.449, number of correct bits 19880
# step 72800, loss is 370.154, number of correct bits 19892
# step 72900, loss is 401.007, number of correct bits 19880
# step 73000, loss is 290.546, number of correct bits 19918
# step 73100, loss is 374.102, number of correct bits 19898
# step 73200, loss is 415.956, number of correct bits 19875
# step 73300, loss is 391.504, number of correct bits 19877
# step 73400, loss is 413.739, number of correct bits 19877
# step 73500, loss is 350.498, number of correct bits 19903
# step 73600, loss is 369.851, number of correct bits 19890
# step 73700, loss is 323.158, number of correct bits 19912
# step 73800, loss is 422.032, number of correct bits 19875
# step 73900, loss is 434.468, number of correct bits 19872
# step 74000, loss is 384.699, number of correct bits 19887
# step 74100, loss is 357.868, number of correct bits 19894
# step 74200, loss is 353.56, number of correct bits 19890
# step 74300, loss is 315.423, number of correct bits 19903
# step 74400, loss is 399.887, number of correct bits 19882
# step 74500, loss is 427.693, number of correct bits 19870
# step 74600, loss is 358.395, number of correct bits 19894
# step 74700, loss is 396.887, number of correct bits 19885
# step 74800, loss is 345.815, number of correct bits 19896
# step 74900, loss is 356.826, number of correct bits 19884
# step 75000, loss is 295.884, number of correct bits 19921
# step 75100, loss is 354.557, number of correct bits 19900
# step 75200, loss is 386.06, number of correct bits 19885
# step 75300, loss is 314.609, number of correct bits 19921
# step 75400, loss is 425.375, number of correct bits 19881
# step 75500, loss is 355.098, number of correct bits 19900
# step 75600, loss is 419.119, number of correct bits 19875
# step 75700, loss is 419.957, number of correct bits 19870
# step 75800, loss is 351.794, number of correct bits 19900
# step 75900, loss is 351.674, number of correct bits 19908
# step 76000, loss is 339.917, number of correct bits 19901
# step 76100, loss is 367.629, number of correct bits 19886
# step 76200, loss is 389.9, number of correct bits 19898
# step 76300, loss is 365.079, number of correct bits 19893
# step 76400, loss is 419.606, number of correct bits 19877
# step 76500, loss is 380.181, number of correct bits 19870
# step 76600, loss is 322.056, number of correct bits 19911
# step 76700, loss is 421.406, number of correct bits 19881
# step 76800, loss is 391.159, number of correct bits 19884
# step 76900, loss is 361.19, number of correct bits 19897
# step 77000, loss is 402.599, number of correct bits 19885
# step 77100, loss is 407.058, number of correct bits 19870
# step 77200, loss is 347.715, number of correct bits 19898
# step 77300, loss is 417.285, number of correct bits 19881
# step 77400, loss is 420.132, number of correct bits 19869
# step 77500, loss is 375.966, number of correct bits 19887
# step 77600, loss is 355.743, number of correct bits 19896
# step 77700, loss is 329.053, number of correct bits 19910
# step 77800, loss is 416.246, number of correct bits 19876
# step 77900, loss is 389.109, number of correct bits 19887
# step 78000, loss is 345.185, number of correct bits 19904
# step 78100, loss is 379.131, number of correct bits 19889
# step 78200, loss is 382.041, number of correct bits 19890
# step 78300, loss is 343.107, number of correct bits 19906
# step 78400, loss is 378.78, number of correct bits 19888
# step 78500, loss is 357.636, number of correct bits 19901
# step 78600, loss is 344.221, number of correct bits 19899
# step 78700, loss is 363.985, number of correct bits 19901
# step 78800, loss is 376.589, number of correct bits 19889
# step 78900, loss is 378.401, number of correct bits 19894
# step 79000, loss is 372.873, number of correct bits 19899
# step 79100, loss is 374.782, number of correct bits 19895
# step 79200, loss is 374.597, number of correct bits 19886
# step 79300, loss is 355.168, number of correct bits 19893
# step 79400, loss is 346.681, number of correct bits 19899
# step 79500, loss is 355.428, number of correct bits 19898
# step 79600, loss is 317.397, number of correct bits 19913
# step 79700, loss is 338.171, number of correct bits 19900
# step 79800, loss is 398.311, number of correct bits 19886
# step 79900, loss is 358.641, number of correct bits 19902
# step 80000, loss is 377.753, number of correct bits 19899
# step 80100, loss is 363.402, number of correct bits 19891
# step 80200, loss is 380.974, number of correct bits 19890
# step 80300, loss is 425.151, number of correct bits 19880
# step 80400, loss is 337.443, number of correct bits 19899
# step 80500, loss is 371.064, number of correct bits 19889
# step 80600, loss is 357.892, number of correct bits 19897
# step 80700, loss is 403.51, number of correct bits 19869
# step 80800, loss is 304.158, number of correct bits 19921
# step 80900, loss is 371.714, number of correct bits 19897
# step 81000, loss is 330.232, number of correct bits 19905
# step 81100, loss is 382.222, number of correct bits 19885
# step 81200, loss is 369.255, number of correct bits 19889
# step 81300, loss is 404.164, number of correct bits 19880
# step 81400, loss is 337.156, number of correct bits 19903
# step 81500, loss is 345.843, number of correct bits 19904
# step 81600, loss is 361.199, number of correct bits 19903
# step 81700, loss is 377.933, number of correct bits 19893
# step 81800, loss is 291.855, number of correct bits 19926
# step 81900, loss is 384.679, number of correct bits 19883
# step 82000, loss is 328.9, number of correct bits 19904
# step 82100, loss is 376.936, number of correct bits 19895
# step 82200, loss is 334.056, number of correct bits 19901
# step 82300, loss is 348.436, number of correct bits 19899
# step 82400, loss is 345.983, number of correct bits 19905
# step 82500, loss is 355.855, number of correct bits 19898
# step 82600, loss is 327.143, number of correct bits 19909
# step 82700, loss is 428.98, number of correct bits 19875
# step 82800, loss is 395.22, number of correct bits 19885
# step 82900, loss is 408.518, number of correct bits 19879
# step 83000, loss is 269.836, number of correct bits 19929
# ...
# step 975500, loss is 266.807, number of correct bits 19916
# step 975600, loss is 235.258, number of correct bits 19921
# step 975700, loss is 261.578, number of correct bits 19920
# step 975800, loss is 251.704, number of correct bits 19920
# step 975900, loss is 301.06, number of correct bits 19903
# step 976000, loss is 311.775, number of correct bits 19900
# step 976100, loss is 261.316, number of correct bits 19919
# step 976200, loss is 270.281, number of correct bits 19912
# step 976300, loss is 255.666, number of correct bits 19921
# step 976400, loss is 200.11, number of correct bits 19938
# step 976500, loss is 223.65, number of correct bits 19932
# step 976600, loss is 238.889, number of correct bits 19920
# step 976700, loss is 259.181, number of correct bits 19919
# step 976800, loss is 236.413, number of correct bits 19927
# step 976900, loss is 244.266, number of correct bits 19924
# step 977000, loss is 278.588, number of correct bits 19911
# step 977100, loss is 277.938, number of correct bits 19921
# step 977200, loss is 299.821, number of correct bits 19903
# step 977300, loss is 236.717, number of correct bits 19925
# step 977400, loss is 265.307, number of correct bits 19919
# step 977500, loss is 213.229, number of correct bits 19927
# step 977600, loss is 241.075, number of correct bits 19929
# step 977700, loss is 263.306, number of correct bits 19913
# step 977800, loss is 227.32, number of correct bits 19929
# step 977900, loss is 308.125, number of correct bits 19907
# step 978000, loss is 253.95, number of correct bits 19921
# step 978100, loss is 211.141, number of correct bits 19935
# step 978200, loss is 228.692, number of correct bits 19928
# step 978300, loss is 284.316, number of correct bits 19909
# step 978400, loss is 278.286, number of correct bits 19914
# step 978500, loss is 277.344, number of correct bits 19915
# step 978600, loss is 269.96, number of correct bits 19924
# step 978700, loss is 281.061, number of correct bits 19915
# step 978800, loss is 219.932, number of correct bits 19936
# step 978900, loss is 269.17, number of correct bits 19921
# step 979000, loss is 285.601, number of correct bits 19910
# step 979100, loss is 224.367, number of correct bits 19935
# step 979200, loss is 222.767, number of correct bits 19930
# step 979300, loss is 280.372, number of correct bits 19909
# step 979400, loss is 250.592, number of correct bits 19925
# step 979500, loss is 252.651, number of correct bits 19928
# step 979600, loss is 282.12, number of correct bits 19909
# step 979700, loss is 267.147, number of correct bits 19913
# step 979800, loss is 276.945, number of correct bits 19916
# step 979900, loss is 270.88, number of correct bits 19922
# step 980000, loss is 227.269, number of correct bits 19930
# step 980100, loss is 301.447, number of correct bits 19903
# step 980200, loss is 253.157, number of correct bits 19918
# step 980300, loss is 203.084, number of correct bits 19934
# step 980400, loss is 252.598, number of correct bits 19927
# step 980500, loss is 219.977, number of correct bits 19932
# step 980600, loss is 266.358, number of correct bits 19914
# step 980700, loss is 299.578, number of correct bits 19906
# step 980800, loss is 248.376, number of correct bits 19921
# step 980900, loss is 230.234, number of correct bits 19925
# step 981000, loss is 309.445, number of correct bits 19894
# step 981100, loss is 251.105, number of correct bits 19918
# step 981200, loss is 237.284, number of correct bits 19929
# step 981300, loss is 240.863, number of correct bits 19930
# step 981400, loss is 293.374, number of correct bits 19909
# step 981500, loss is 263.031, number of correct bits 19916
# step 981600, loss is 280.125, number of correct bits 19908
# step 981700, loss is 246.415, number of correct bits 19923
# step 981800, loss is 318.078, number of correct bits 19907
# step 981900, loss is 274.699, number of correct bits 19917
# step 982000, loss is 232.272, number of correct bits 19932
# step 982100, loss is 307.281, number of correct bits 19907
# step 982200, loss is 272.754, number of correct bits 19913
# step 982300, loss is 238.641, number of correct bits 19924
# step 982400, loss is 222.196, number of correct bits 19929
# step 982500, loss is 291.514, number of correct bits 19910
# step 982600, loss is 234.791, number of correct bits 19928
# step 982700, loss is 294.352, number of correct bits 19902
# step 982800, loss is 270.788, number of correct bits 19911
# step 982900, loss is 205.732, number of correct bits 19936
# step 983000, loss is 283.019, number of correct bits 19916
# step 983100, loss is 285.541, number of correct bits 19910
# step 983200, loss is 248.775, number of correct bits 19922
# step 983300, loss is 221.981, number of correct bits 19930
# step 983400, loss is 298.515, number of correct bits 19905
# step 983500, loss is 286.197, number of correct bits 19909
# step 983600, loss is 303.203, number of correct bits 19909
# step 983700, loss is 261.652, number of correct bits 19919
# step 983800, loss is 329.698, number of correct bits 19891
# step 983900, loss is 231.877, number of correct bits 19928
# step 984000, loss is 321.599, number of correct bits 19895
# step 984100, loss is 224.851, number of correct bits 19928
# step 984200, loss is 288.168, number of correct bits 19909
# step 984300, loss is 341.191, number of correct bits 19890
# step 984400, loss is 221.38, number of correct bits 19932
# step 984500, loss is 218.028, number of correct bits 19933
# step 984600, loss is 228.515, number of correct bits 19931
# step 984700, loss is 279.595, number of correct bits 19915
# step 984800, loss is 296.737, number of correct bits 19906
# step 984900, loss is 254.173, number of correct bits 19918
# step 985000, loss is 185.134, number of correct bits 19944
# step 985100, loss is 322.468, number of correct bits 19896
# step 985200, loss is 254.476, number of correct bits 19919
# step 985300, loss is 316.144, number of correct bits 19905
# step 985400, loss is 244.495, number of correct bits 19922
# step 985500, loss is 291.433, number of correct bits 19904
# step 985600, loss is 274.247, number of correct bits 19914
# step 985700, loss is 275.056, number of correct bits 19916
# step 985800, loss is 273.323, number of correct bits 19909
# step 985900, loss is 309.993, number of correct bits 19906
# step 986000, loss is 192.994, number of correct bits 19939
# step 986100, loss is 281.382, number of correct bits 19905
# step 986200, loss is 270.428, number of correct bits 19916
# step 986300, loss is 321.097, number of correct bits 19896
# step 986400, loss is 280.956, number of correct bits 19910
# step 986500, loss is 310.816, number of correct bits 19895
# step 986600, loss is 209.255, number of correct bits 19933
# step 986700, loss is 193.942, number of correct bits 19940
# step 986800, loss is 237.135, number of correct bits 19932
# step 986900, loss is 208.252, number of correct bits 19936
# step 987000, loss is 253.457, number of correct bits 19922
# step 987100, loss is 242.78, number of correct bits 19931
# step 987200, loss is 263.474, number of correct bits 19918
# step 987300, loss is 322.268, number of correct bits 19891
# step 987400, loss is 237.274, number of correct bits 19927
# step 987500, loss is 293.158, number of correct bits 19913
# step 987600, loss is 270.332, number of correct bits 19909
# step 987700, loss is 259.069, number of correct bits 19920
# step 987800, loss is 284.273, number of correct bits 19921
# step 987900, loss is 212.847, number of correct bits 19937
# step 988000, loss is 213.667, number of correct bits 19936
# step 988100, loss is 300.53, number of correct bits 19909
# step 988200, loss is 285.476, number of correct bits 19914
# step 988300, loss is 218.908, number of correct bits 19933
# step 988400, loss is 260.171, number of correct bits 19919
# step 988500, loss is 283.46, number of correct bits 19910
# step 988600, loss is 278.15, number of correct bits 19914
# step 988700, loss is 334.132, number of correct bits 19893
# step 988800, loss is 259.157, number of correct bits 19921
# step 988900, loss is 315.55, number of correct bits 19908
# step 989000, loss is 314.965, number of correct bits 19901
# step 989100, loss is 330.475, number of correct bits 19894
# step 989200, loss is 264.69, number of correct bits 19912
# step 989300, loss is 233.979, number of correct bits 19924
# step 989400, loss is 285.563, number of correct bits 19909
# step 989500, loss is 265.766, number of correct bits 19913
# step 989600, loss is 270.727, number of correct bits 19920
# step 989700, loss is 279.659, number of correct bits 19913
# step 989800, loss is 213.509, number of correct bits 19933
# step 989900, loss is 236.646, number of correct bits 19928
# step 990000, loss is 267.813, number of correct bits 19920
# step 990100, loss is 232.878, number of correct bits 19932
# step 990200, loss is 230.08, number of correct bits 19925
# step 990300, loss is 303.01, number of correct bits 19910
# step 990400, loss is 270.656, number of correct bits 19911
# step 990500, loss is 194.053, number of correct bits 19937
# step 990600, loss is 208.985, number of correct bits 19941
# step 990700, loss is 234.008, number of correct bits 19935
# step 990800, loss is 291.888, number of correct bits 19904
# step 990900, loss is 246.874, number of correct bits 19922
# step 991000, loss is 326.283, number of correct bits 19905
# step 991100, loss is 282.514, number of correct bits 19907
# step 991200, loss is 201.911, number of correct bits 19938
# step 991300, loss is 295.577, number of correct bits 19909
# step 991400, loss is 301.922, number of correct bits 19900
# step 991500, loss is 225.251, number of correct bits 19931
# step 991600, loss is 214.488, number of correct bits 19930
# step 991700, loss is 278.206, number of correct bits 19912
# step 991800, loss is 280.925, number of correct bits 19919
# step 991900, loss is 230.459, number of correct bits 19929
# step 992000, loss is 290.991, number of correct bits 19912
# step 992100, loss is 239.224, number of correct bits 19923
# step 992200, loss is 278.996, number of correct bits 19910
# step 992300, loss is 273.259, number of correct bits 19906
# step 992400, loss is 257.768, number of correct bits 19914
# step 992500, loss is 315.356, number of correct bits 19902
# step 992600, loss is 257.194, number of correct bits 19924
# step 992700, loss is 274.669, number of correct bits 19914
# step 992800, loss is 251.301, number of correct bits 19918
# step 992900, loss is 277.511, number of correct bits 19912
# step 993000, loss is 256.578, number of correct bits 19916
# step 993100, loss is 308.242, number of correct bits 19902
# step 993200, loss is 250.74, number of correct bits 19922
# step 993300, loss is 253.549, number of correct bits 19926
# step 993400, loss is 275.279, number of correct bits 19920
# step 993500, loss is 211.422, number of correct bits 19933
# step 993600, loss is 241.991, number of correct bits 19921
# step 993700, loss is 226.177, number of correct bits 19927
# step 993800, loss is 263.619, number of correct bits 19915
# step 993900, loss is 301.457, number of correct bits 19907
# step 994000, loss is 235.822, number of correct bits 19929
# step 994100, loss is 247.175, number of correct bits 19923
# step 994200, loss is 245.879, number of correct bits 19925
# step 994300, loss is 255.769, number of correct bits 19909
# step 994400, loss is 296.915, number of correct bits 19898
# step 994500, loss is 343.161, number of correct bits 19892
# step 994600, loss is 274.282, number of correct bits 19912
# step 994700, loss is 271.044, number of correct bits 19925
# step 994800, loss is 230.592, number of correct bits 19927
# step 994900, loss is 301.349, number of correct bits 19907
# step 995000, loss is 238.703, number of correct bits 19924
# step 995100, loss is 215.958, number of correct bits 19933
# step 995200, loss is 304.308, number of correct bits 19904
# step 995300, loss is 243.588, number of correct bits 19926
# step 995400, loss is 257.01, number of correct bits 19923
# step 995500, loss is 244.714, number of correct bits 19928
# step 995600, loss is 312.589, number of correct bits 19910
# step 995700, loss is 269.471, number of correct bits 19913
# step 995800, loss is 229.353, number of correct bits 19931
# step 995900, loss is 240.14, number of correct bits 19927
# step 996000, loss is 216.418, number of correct bits 19939
# step 996100, loss is 219.547, number of correct bits 19938
# step 996200, loss is 336.789, number of correct bits 19897
# step 996300, loss is 270.709, number of correct bits 19912
# step 996400, loss is 229.739, number of correct bits 19928
# step 996500, loss is 217.726, number of correct bits 19934
# step 996600, loss is 251.695, number of correct bits 19921
# step 996700, loss is 279.426, number of correct bits 19912
# step 996800, loss is 279.782, number of correct bits 19903
# step 996900, loss is 323.48, number of correct bits 19898
# step 997000, loss is 243.004, number of correct bits 19928
# step 997100, loss is 297.987, number of correct bits 19899
# step 997200, loss is 257.461, number of correct bits 19923
# step 997300, loss is 276.097, number of correct bits 19918
# step 997400, loss is 263.348, number of correct bits 19920
# step 997500, loss is 295.929, number of correct bits 19907
# step 997600, loss is 242.624, number of correct bits 19923
# step 997700, loss is 289.904, number of correct bits 19913
# step 997800, loss is 213.229, number of correct bits 19938
# step 997900, loss is 214.152, number of correct bits 19934
# step 998000, loss is 211.853, number of correct bits 19929
# step 998100, loss is 224.867, number of correct bits 19931
# step 998200, loss is 217.055, number of correct bits 19927
# step 998300, loss is 226.789, number of correct bits 19932
# step 998400, loss is 249.321, number of correct bits 19921
# step 998500, loss is 274.454, number of correct bits 19915
# step 998600, loss is 210.36, number of correct bits 19935
# step 998700, loss is 228.979, number of correct bits 19930
# step 998800, loss is 243.072, number of correct bits 19923
# step 998900, loss is 263.798, number of correct bits 19920
# step 999000, loss is 289.808, number of correct bits 19905
# step 999100, loss is 268.327, number of correct bits 19915
# step 999200, loss is 232.425, number of correct bits 19925
# step 999300, loss is 244.382, number of correct bits 19924
# step 999400, loss is 339.259, number of correct bits 19889
# step 999500, loss is 273.524, number of correct bits 19916
# step 999600, loss is 240.784, number of correct bits 19922
# step 999700, loss is 318.061, number of correct bits 19902
# step 999800, loss is 241.404, number of correct bits 19924
# step 999900, loss is 211.511, number of correct bits 19936
# cur snr
# 6.309573444801933
# test accuracy 19635
# test accuracy 19593
# test accuracy 19624
# test accuracy 19597
# test accuracy 19620
# test accuracy 19632
# test accuracy 19590
# test accuracy 19610
# test accuracy 19614
# test accuracy 19599
# cur snr
# 7.943282347242816
# test accuracy 19785
# test accuracy 19784
# test accuracy 19801
# test accuracy 19808
# test accuracy 19781
# test accuracy 19795
# test accuracy 19774
# test accuracy 19820
# test accuracy 19768
# test accuracy 19822
# cur snr
# 10.0
# test accuracy 19915
# test accuracy 19913
# test accuracy 19913
# test accuracy 19920
# test accuracy 19930
# test accuracy 19926
# test accuracy 19941
# test accuracy 19937
# test accuracy 19899
# test accuracy 19915
# cur snr
# 12.589254117941675
# test accuracy 19981
# test accuracy 19961
# test accuracy 19972
# test accuracy 19980
# test accuracy 19977
# test accuracy 19969
# test accuracy 19969
# test accuracy 19972
# test accuracy 19970
# test accuracy 19977
# cur snr
# 15.848931924611133
# test accuracy 19991
# test accuracy 19990
# test accuracy 19995
# test accuracy 19994
# test accuracy 19997
# test accuracy 19993
# test accuracy 19997
# test accuracy 19996
# test accuracy 19998
# test accuracy 19995
# cur snr
# 19.952623149688797
# test accuracy 19999
# test accuracy 19999
# test accuracy 20000
# test accuracy 19999
# test accuracy 19998
# test accuracy 20000
# test accuracy 20000
# test accuracy 19998
# test accuracy 19999
# test accuracy 19998
# Average time to detect a single K bit signal is:
# [[4.82195783e-06]]
# snrdb_list
# [ 8.  9. 10. 11. 12. 13.]
# Bit error rates are is:
# [[1.991815e-02 9.846600e-03 4.032200e-03 1.335800e-03 3.513500e-04
#   6.330000e-05]]
