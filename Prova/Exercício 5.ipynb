# %% [markdown]
# # Exercício 5

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# Atributos:
# Possuir Casa (PC), Estado civil (EC), Experiência (EX).
#
# Classes:
# Sim (Pagou), Não (Não Pagou).

# %% [markdown]
# Cálculo da entropia:
# H(y) = [12/7.log2(12/17)+(1-12/17).log2(1-12/17)]
# H(y) = 0,874

# %%
img=mpimg.imread('T5.1.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# G(PC) = 0,874-[7/17.H(6/17)+10/17.H(6/10)]
# G(PC) = 0,874-[7/17.0,5917+10/17.0,971]
# G(PC) = 0,392

# %%
img=mpimg.imread('T5.2.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# G(EC) = 0,874-[5/17.H(4/5)+8/17.H(6/8)+4/17.H(2/4)]
# G(EC) = 0,874-[5/17.0,7219+8/17.0,8113+4/7.1]
# G(EC) = 0,0446

# %%
img=mpimg.imread('T5.3.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# G(EX) = 0,874-[6/17.H(3/6)+6/17.H(4/6)+4/17.H(1)+1/17.H(1)]
# G(EX) = 0,874-[6/17.1+6/17.0,9783]
# G(EX) = 0,197
#
# O G(EX), foi o que apresentou o maior valor, sendo assim, experiência é dada como o nó raiz da árvore.

# %% [markdown]
# Subconjuntos de EX:

# %%
img=mpimg.imread('T5.4.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread('T5.5.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread('T5.6.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Para todos os casos em que a experiência é igual a 4, y sempre assume o valor 'sim'.

# %%
img=mpimg.imread('T5.7.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Para o único caso em que a experiência é igual a 5, y assume o valor 'sim'.

# %% [markdown]
# Abaixo, são apresentados os cálculos, considerando EX=2:

# %%
img=mpimg.imread('T5.8.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Cálculo da entropia para a subclasse:
# H(sbcl) = -[3/6.log2(3/6) + (1-3/6).log2(1-3/6)]
# H(sbcl) = 1
#
# G(PC) = 1-[3/6.H(2/3)+3/6.H(1/3)]
# G(PC) = 1-[3/6.0,9183+3/6.0,459]
# G(PC) = 0,311
#
# G(EC) = 1-[2/3.H(1/2)+2/6.H(1/2)+2/6.H(1/2)]
# G(EC) = 1-[3.1/3]
# G(EC) = 0
#
# Dado os ganhos calculados acima, conclui-se que o G(PC) possui maior valor.

# %%
img=mpimg.imread('T5.9.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread('T5.10.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Abaixo, são apresentados os cálculos, considerando EX=3:

# %%
img=mpimg.imread('T5.11.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Cálculo da entropia para a subclasse:
# H(sbcl) = -[4/6.log2(4/6) + (1-4/6).log2(1-4/6)]
# H(sbcl) = 0,92
#
# G(PC) = 0,92-[3/6.H(3/3)+3/6.H(1/3)]
# G(PC) = 0,92-[3/6.0,9183]
# G(PC) = 0,461
#
# G(EC) = 0,92-[2/6.H(2/2)+2/6.H(1/2)+2/6.H(1/2)]
# G(EC) = 0,92-[1/3+1/3]
# G(EC) = 0,253
#
# Dos cálculos realizados acima, o que apresenta o maior valor é o G(PC).

# %%
img=mpimg.imread('T5.12.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Das tabelas geradas acima, conclui-se que, se EX=3 e PC=S, Y assume o valor 'Sim'.

# %% [markdown]
# A árvore resultante, aparece no desenho abaixo (feito a mão, da resolução que também está na pasta da prova no GitHub, de nome 'Exercício 5 - Resolução').

# %%
fig = plt.figure(figsize=(15,15))
img=mpimg.imread('T5.A.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Atributos de Jair:
# Possui Casa: Não;
# Estado civil: Casado;
# Experiência: 3;
#
# Considerando os atributos de Jair e a árvore montada acima, não se deve emprestar dinheiro a ele.
